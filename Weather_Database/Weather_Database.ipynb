# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 752

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | zlobin
# Processing Record 2 of the Set 1 | lobito
# Processing Record 3 of the Set 1 | mataura
# Processing Record 4 of the Set 1 | grand gaube
# Processing Record 5 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of the Set 1 | kyzyl-suu
# Processing Record 7 of the Set 1 | rikitea
# Processing Record 8 of the Set 1 | coahuayana
# Processing Record 9 of the Set 1 | busselton
# Processing Record 10 of the Set 1 | kuytun
# Processing Record 11 of the Set 1 | yulara
# Processing Record 12 of the Set 1 | valparaiso
# Processing Record 13 of the Set 1 | tuktoyaktuk
# Processing Record 14 of the Set 1 | muisne
# Processing Record 15 of the Set 1 | new norfolk
# Processing Record 16 of the Set 1 | namatanai
# Processing Record 17 of the Set 1 | khatanga
# Processing Record 18 of the Set 1 | asosa
# Processing Record 19 of the Set 1 | songea
# Processing Record 20 of the Set 1 | jamestown
# Processing Record 21 of the Set 1 | kapaa
# Processing Record 22 of the Set 1 | kodiak
# Processing Record 23 of the Set 1 | clearwater
# Processing Record 24 of the Set 1 | port alfred
# Processing Record 25 of the Set 1 | bluff
# Processing Record 26 of the Set 1 | ukiah
# Processing Record 27 of the Set 1 | sentyabrskiy
# Processing Record 28 of the Set 1 | talnakh
# Processing Record 29 of the Set 1 | havelock
# Processing Record 30 of the Set 1 | albany
# Processing Record 31 of the Set 1 | hithadhoo
# Processing Record 32 of the Set 1 | arraial do cabo
# Processing Record 33 of the Set 1 | nikolskoye
# Processing Record 34 of the Set 1 | saint-philippe
# Processing Record 35 of the Set 1 | avarua
# Processing Record 36 of the Set 1 | maghama
# City not found. Skipping...
# Processing Record 37 of the Set 1 | barrow
# Processing Record 38 of the Set 1 | saldanha
# Processing Record 39 of the Set 1 | yellowknife
# Processing Record 40 of the Set 1 | hobart
# Processing Record 41 of the Set 1 | kadykchan
# Processing Record 42 of the Set 1 | castro
# Processing Record 43 of the Set 1 | christchurch
# Processing Record 44 of the Set 1 | marcona
# City not found. Skipping...
# Processing Record 45 of the Set 1 | vaini
# Processing Record 46 of the Set 1 | ormara
# Processing Record 47 of the Set 1 | cape town
# Processing Record 48 of the Set 1 | beringovskiy
# Processing Record 49 of the Set 1 | butaritari
# Processing Record 50 of the Set 1 | nuuk
# Processing Record 1 of the Set 2 | belushya guba
# Processing Record 2 of the Set 2 | hilo
# Processing Record 3 of the Set 2 | igrim
# Processing Record 4 of the Set 2 | makakilo city
# Processing Record 5 of the Set 2 | cayambe
# Processing Record 6 of the Set 2 | paracuru
# Processing Record 7 of the Set 2 | punta arenas
# Processing Record 8 of the Set 2 | ixtapa
# Processing Record 9 of the Set 2 | tasiilaq
# Processing Record 10 of the Set 2 | chicama
# City not found. Skipping...
# Processing Record 11 of the Set 2 | freeport
# Processing Record 12 of the Set 2 | mar del plata
# Processing Record 13 of the Set 2 | pekan
# Processing Record 14 of the Set 2 | gidole
# Processing Record 15 of the Set 2 | baijiantan
# Processing Record 16 of the Set 2 | shimoda
# Processing Record 17 of the Set 2 | ushuaia
# Processing Record 18 of the Set 2 | shingu
# Processing Record 19 of the Set 2 | bredasdorp
# Processing Record 20 of the Set 2 | ewa beach
# Processing Record 21 of the Set 2 | poum
# Processing Record 22 of the Set 2 | seydi
# Processing Record 23 of the Set 2 | leningradskiy
# Processing Record 24 of the Set 2 | pskov
# Processing Record 25 of the Set 2 | omsukchan
# Processing Record 26 of the Set 2 | bethel
# Processing Record 27 of the Set 2 | lagoa
# Processing Record 28 of the Set 2 | upernavik
# Processing Record 29 of the Set 2 | doha
# Processing Record 30 of the Set 2 | dikson
# Processing Record 31 of the Set 2 | killybegs
# Processing Record 32 of the Set 2 | georgetown
# Processing Record 33 of the Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of the Set 2 | abu dhabi
# Processing Record 35 of the Set 2 | mumford
# Processing Record 36 of the Set 2 | amot
# Processing Record 37 of the Set 2 | suntar
# Processing Record 38 of the Set 2 | esperance
# Processing Record 39 of the Set 2 | irbeyskoye
# Processing Record 40 of the Set 2 | mahebourg
# Processing Record 41 of the Set 2 | guipavas
# Processing Record 42 of the Set 2 | chokurdakh
# Processing Record 43 of the Set 2 | hermanus
# Processing Record 44 of the Set 2 | nurobod
# Processing Record 45 of the Set 2 | flinders
# Processing Record 46 of the Set 2 | yuxia
# Processing Record 47 of the Set 2 | codrington
# Processing Record 48 of the Set 2 | louisbourg
# Processing Record 49 of the Set 2 | mount gambier
# Processing Record 50 of the Set 2 | east london
# Processing Record 1 of the Set 3 | hays
# Processing Record 2 of the Set 3 | lebu
# Processing Record 3 of the Set 3 | margate
# Processing Record 4 of the Set 3 | san felipe
# Processing Record 5 of the Set 3 | tabou
# Processing Record 6 of the Set 3 | linkoping
# Processing Record 7 of the Set 3 | coquimbo
# Processing Record 8 of the Set 3 | saskylakh
# Processing Record 9 of the Set 3 | qeshm
# Processing Record 10 of the Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of the Set 3 | arroyo
# Processing Record 12 of the Set 3 | emerald
# Processing Record 13 of the Set 3 | campbellton
# Processing Record 14 of the Set 3 | cherskiy
# Processing Record 15 of the Set 3 | ahuimanu
# Processing Record 16 of the Set 3 | kyra
# Processing Record 17 of the Set 3 | zhigansk
# Processing Record 18 of the Set 3 | dawei
# Processing Record 19 of the Set 3 | severo-kurilsk
# Processing Record 20 of the Set 3 | la ronge
# Processing Record 21 of the Set 3 | impfondo
# Processing Record 22 of the Set 3 | tumannyy
# Processing Record 23 of the Set 3 | geraldton
# Processing Record 24 of the Set 3 | omboue
# Processing Record 25 of the Set 3 | sisimiut
# Processing Record 26 of the Set 3 | wau
# Processing Record 27 of the Set 3 | puerto ayora
# Processing Record 28 of the Set 3 | aklavik
# Processing Record 29 of the Set 3 | awjilah
# Processing Record 30 of the Set 3 | dudinka
# Processing Record 31 of the Set 3 | tura
# Processing Record 32 of the Set 3 | bosaso
# Processing Record 33 of the Set 3 | port macquarie
# Processing Record 34 of the Set 3 | sao filipe
# Processing Record 35 of the Set 3 | awbari
# Processing Record 36 of the Set 3 | erenhot
# Processing Record 37 of the Set 3 | redlands
# Processing Record 38 of the Set 3 | mareeba
# Processing Record 39 of the Set 3 | caruray
# Processing Record 40 of the Set 3 | kamenskoye
# Processing Record 41 of the Set 3 | tommot
# Processing Record 42 of the Set 3 | kosh-agach
# Processing Record 43 of the Set 3 | lata
# Processing Record 44 of the Set 3 | muros
# Processing Record 45 of the Set 3 | sangar
# Processing Record 46 of the Set 3 | wukari
# Processing Record 47 of the Set 3 | vagay
# Processing Record 48 of the Set 3 | kulhudhuffushi
# Processing Record 49 of the Set 3 | iguai
# Processing Record 50 of the Set 3 | norman wells
# Processing Record 1 of the Set 4 | atuona
# Processing Record 2 of the Set 4 | puerto del rosario
# Processing Record 3 of the Set 4 | faanui
# Processing Record 4 of the Set 4 | pasighat
# Processing Record 5 of the Set 4 | kidal
# Processing Record 6 of the Set 4 | chapais
# Processing Record 7 of the Set 4 | heinola
# Processing Record 8 of the Set 4 | luderitz
# Processing Record 9 of the Set 4 | ardistan
# Processing Record 10 of the Set 4 | mys shmidta
# Processing Record 11 of the Set 4 | porto novo
# Processing Record 12 of the Set 4 | ternate
# Processing Record 13 of the Set 4 | ciudanovita
# City not found. Skipping...
# Processing Record 14 of the Set 4 | bambous virieux
# Processing Record 15 of the Set 4 | wasilla
# Processing Record 16 of the Set 4 | camana
# City not found. Skipping...
# Processing Record 17 of the Set 4 | saint anthony
# Processing Record 18 of the Set 4 | constitucion
# Processing Record 19 of the Set 4 | ribeira grande
# Processing Record 20 of the Set 4 | tidore
# Processing Record 21 of the Set 4 | galiwinku
# Processing Record 22 of the Set 4 | samarai
# Processing Record 23 of the Set 4 | sile
# Processing Record 24 of the Set 4 | svetlaya
# Processing Record 25 of the Set 4 | krasnouralsk
# Processing Record 26 of the Set 4 | moberly
# Processing Record 27 of the Set 4 | avera
# Processing Record 28 of the Set 4 | hualmay
# City not found. Skipping...
# Processing Record 29 of the Set 4 | chimoio
# Processing Record 30 of the Set 4 | dunedin
# Processing Record 31 of the Set 4 | longyearbyen
# Processing Record 32 of the Set 4 | ubinskoye
# Processing Record 33 of the Set 4 | nizwa
# Processing Record 34 of the Set 4 | lavrentiya
# Processing Record 35 of the Set 4 | port lincoln
# Processing Record 36 of the Set 4 | grand river south east
# Processing Record 37 of the Set 4 | vostok
# Processing Record 38 of the Set 4 | torbay
# Processing Record 39 of the Set 4 | berlevag
# Processing Record 40 of the Set 4 | bengkulu
# Processing Record 41 of the Set 4 | silifke
# Processing Record 42 of the Set 4 | tuatapere
# Processing Record 43 of the Set 4 | yangjiang
# Processing Record 44 of the Set 4 | duncan
# Processing Record 45 of the Set 4 | corum
# Processing Record 46 of the Set 4 | bandarbeyla
# Processing Record 47 of the Set 4 | umzimvubu
# Processing Record 48 of the Set 4 | susangerd
# Processing Record 49 of the Set 4 | quatre cocos
# Processing Record 50 of the Set 4 | sorgun
# Processing Record 1 of the Set 5 | nanortalik
# Processing Record 2 of the Set 5 | carnarvon
# Processing Record 3 of the Set 5 | thompson
# Processing Record 4 of the Set 5 | huanren
# Processing Record 5 of the Set 5 | buala
# Processing Record 6 of the Set 5 | roma
# Processing Record 7 of the Set 5 | walvis bay
# Processing Record 8 of the Set 5 | wadena
# Processing Record 9 of the Set 5 | roald
# Processing Record 10 of the Set 5 | qasigiannguit
# Processing Record 11 of the Set 5 | husavik
# Processing Record 12 of the Set 5 | sitka
# Processing Record 13 of the Set 5 | aripuana
# Processing Record 14 of the Set 5 | skibbereen
# Processing Record 15 of the Set 5 | pokhara
# Processing Record 16 of the Set 5 | abnub
# Processing Record 17 of the Set 5 | alice springs
# Processing Record 18 of the Set 5 | nikki
# Processing Record 19 of the Set 5 | abilene
# Processing Record 20 of the Set 5 | choya
# Processing Record 21 of the Set 5 | qaanaaq
# Processing Record 22 of the Set 5 | clyde river
# Processing Record 23 of the Set 5 | makinsk
# Processing Record 24 of the Set 5 | ponta do sol
# Processing Record 25 of the Set 5 | sorvag
# City not found. Skipping...
# Processing Record 26 of the Set 5 | khirkiya
# Processing Record 27 of the Set 5 | trairi
# Processing Record 28 of the Set 5 | show low
# Processing Record 29 of the Set 5 | falealupo
# City not found. Skipping...
# Processing Record 30 of the Set 5 | barentsburg
# Processing Record 31 of the Set 5 | saint george
# Processing Record 32 of the Set 5 | nortelandia
# Processing Record 33 of the Set 5 | narrabri
# Processing Record 34 of the Set 5 | puerto madryn
# Processing Record 35 of the Set 5 | itarema
# Processing Record 36 of the Set 5 | oktyabrskiy
# Processing Record 37 of the Set 5 | ghanzi
# Processing Record 38 of the Set 5 | ambilobe
# City not found. Skipping...
# Processing Record 39 of the Set 5 | yibin
# Processing Record 40 of the Set 5 | ruatoria
# Processing Record 41 of the Set 5 | san ramon
# Processing Record 42 of the Set 5 | benguela
# Processing Record 43 of the Set 5 | dumas
# Processing Record 44 of the Set 5 | cidreira
# Processing Record 45 of the Set 5 | harindanga
# Processing Record 46 of the Set 5 | lompoc
# Processing Record 47 of the Set 5 | capreol
# Processing Record 48 of the Set 5 | vao
# Processing Record 49 of the Set 5 | amderma
# Processing Record 50 of the Set 5 | tebingtinggi
# Processing Record 1 of the Set 6 | sola
# Processing Record 2 of the Set 6 | saquarema
# Processing Record 3 of the Set 6 | battle creek
# Processing Record 4 of the Set 6 | guerrero negro
# Processing Record 5 of the Set 6 | inhambane
# Processing Record 6 of the Set 6 | samusu
# City not found. Skipping...
# Processing Record 7 of the Set 6 | souillac
# Processing Record 8 of the Set 6 | langxiang
# Processing Record 9 of the Set 6 | hervey bay
# Processing Record 10 of the Set 6 | buraydah
# Processing Record 11 of the Set 6 | vardo
# Processing Record 12 of the Set 6 | ust-ilimsk
# Processing Record 13 of the Set 6 | viligili
# Processing Record 14 of the Set 6 | half moon bay
# Processing Record 15 of the Set 6 | am timan
# Processing Record 16 of the Set 6 | chitral
# Processing Record 17 of the Set 6 | beatrice
# Processing Record 18 of the Set 6 | along
# Processing Record 19 of the Set 6 | san patricio
# Processing Record 20 of the Set 6 | celano
# Processing Record 21 of the Set 6 | agadez
# Processing Record 22 of the Set 6 | maldonado
# Processing Record 23 of the Set 6 | cabo san lucas
# Processing Record 24 of the Set 6 | te anau
# Processing Record 25 of the Set 6 | nzega
# Processing Record 26 of the Set 6 | ayan
# Processing Record 27 of the Set 6 | aksarka
# Processing Record 28 of the Set 6 | kebemer
# City not found. Skipping...
# Processing Record 29 of the Set 6 | santander
# Processing Record 30 of the Set 6 | tallahassee
# Processing Record 31 of the Set 6 | saint-joseph
# Processing Record 32 of the Set 6 | beian
# Processing Record 33 of the Set 6 | oistins
# Processing Record 34 of the Set 6 | tual
# Processing Record 35 of the Set 6 | haimen
# Processing Record 36 of the Set 6 | port-cartier
# Processing Record 37 of the Set 6 | qianguo
# Processing Record 38 of the Set 6 | palabuhanratu
# Processing Record 39 of the Set 6 | korla
# Processing Record 40 of the Set 6 | ouargaye
# Processing Record 41 of the Set 6 | nizhneyansk
# Processing Record 42 of the Set 6 | lerwick
# Processing Record 43 of the Set 6 | abatskoye
# Processing Record 44 of the Set 6 | imbituba
# Processing Record 45 of the Set 6 | kalga
# Processing Record 46 of the Set 6 | san cristobal
# Processing Record 47 of the Set 6 | jawhar
# Processing Record 48 of the Set 6 | acapulco
# Processing Record 49 of the Set 6 | isangel
# Processing Record 50 of the Set 6 | scarborough
# Processing Record 1 of the Set 7 | illoqqortoormiut
# Processing Record 2 of the Set 7 | jasper
# Processing Record 3 of the Set 7 | normandin
# Processing Record 4 of the Set 7 | fortuna
# Processing Record 5 of the Set 7 | we
# Processing Record 6 of the Set 7 | le locle
# Processing Record 7 of the Set 7 | strzelce krajenskie
# Processing Record 8 of the Set 7 | santa rosa
# Processing Record 9 of the Set 7 | iqaluit
# Processing Record 10 of the Set 7 | beidao
# Processing Record 11 of the Set 7 | katsuura
# Processing Record 12 of the Set 7 | garissa
# Processing Record 13 of the Set 7 | araouane
# Processing Record 14 of the Set 7 | pisco
# City not found. Skipping...
# Processing Record 15 of the Set 7 | viedma
# Processing Record 16 of the Set 7 | houma
# Processing Record 17 of the Set 7 | pontianak
# Processing Record 18 of the Set 7 | alamogordo
# Processing Record 19 of the Set 7 | vila velha
# Processing Record 20 of the Set 7 | praia da vitoria
# Processing Record 21 of the Set 7 | northam
# Processing Record 22 of the Set 7 | beyneu
# Processing Record 23 of the Set 7 | rindal
# Processing Record 24 of the Set 7 | provideniya
# Processing Record 25 of the Set 7 | sur
# Processing Record 26 of the Set 7 | dwarka
# Processing Record 27 of the Set 7 | miri
# Processing Record 28 of the Set 7 | ongandjera
# Processing Record 29 of the Set 7 | marrakesh
# Processing Record 30 of the Set 7 | brigantine
# Processing Record 31 of the Set 7 | oranjestad
# Processing Record 32 of the Set 7 | mackay
# Processing Record 33 of the Set 7 | staritsa
# Processing Record 34 of the Set 7 | shelburne
# Processing Record 35 of the Set 7 | kavieng
# Processing Record 36 of the Set 7 | airai
# Processing Record 37 of the Set 7 | yuanping
# Processing Record 38 of the Set 7 | tsienyane
# Processing Record 39 of the Set 7 | orasac
# Processing Record 40 of the Set 7 | ponta delgada
# Processing Record 41 of the Set 7 | pundaguitan
# Processing Record 42 of the Set 7 | baherden
# Processing Record 43 of the Set 7 | akdepe
# Processing Record 44 of the Set 7 | xianyang
# Processing Record 45 of the Set 7 | tiarei
# Processing Record 46 of the Set 7 | pangnirtung
# Processing Record 47 of the Set 7 | vitim
# Processing Record 48 of the Set 7 | ilulissat
# Processing Record 49 of the Set 7 | camocim
# Processing Record 50 of the Set 7 | vung tau
# Processing Record 1 of the Set 8 | bilibino
# Processing Record 2 of the Set 8 | borovoy
# Processing Record 3 of the Set 8 | sahrak
# City not found. Skipping...
# Processing Record 4 of the Set 8 | kichera
# Processing Record 5 of the Set 8 | khandyga
# Processing Record 6 of the Set 8 | kruisfontein
# Processing Record 7 of the Set 8 | havoysund
# Processing Record 8 of the Set 8 | zalantun
# Processing Record 9 of the Set 8 | wenling
# Processing Record 10 of the Set 8 | ilhabela
# Processing Record 11 of the Set 8 | hasaki
# Processing Record 12 of the Set 8 | yakima
# Processing Record 13 of the Set 8 | acarau
# Processing Record 14 of the Set 8 | mount isa
# Processing Record 15 of the Set 8 | kendari
# Processing Record 16 of the Set 8 | puerto madero
# Processing Record 17 of the Set 8 | klimovo
# Processing Record 18 of the Set 8 | nome
# Processing Record 19 of the Set 8 | lucea
# Processing Record 20 of the Set 8 | anloga
# Processing Record 21 of the Set 8 | yumen
# Processing Record 22 of the Set 8 | baoning
# Processing Record 23 of the Set 8 | karratha
# Processing Record 24 of the Set 8 | hami
# Processing Record 25 of the Set 8 | helong
# Processing Record 26 of the Set 8 | channel-port aux basques
# Processing Record 27 of the Set 8 | yeghegnavan
# Processing Record 28 of the Set 8 | ulaanbaatar
# Processing Record 29 of the Set 8 | ambulu
# Processing Record 30 of the Set 8 | faridan
# Processing Record 31 of the Set 8 | victoria
# Processing Record 32 of the Set 8 | saryshagan
# Processing Record 33 of the Set 8 | kailua
# Processing Record 34 of the Set 8 | vidim
# Processing Record 35 of the Set 8 | kutum
# Processing Record 36 of the Set 8 | metu
# Processing Record 37 of the Set 8 | progreso
# Processing Record 38 of the Set 8 | thinadhoo
# Processing Record 39 of the Set 8 | amazar
# Processing Record 40 of the Set 8 | kavaratti
# Processing Record 41 of the Set 8 | port-gentil
# Processing Record 42 of the Set 8 | hay river
# Processing Record 43 of the Set 8 | pishin
# Processing Record 44 of the Set 8 | dongsheng
# Processing Record 45 of the Set 8 | san jeronimo
# Processing Record 46 of the Set 8 | mandawar
# Processing Record 47 of the Set 8 | general roca
# Processing Record 48 of the Set 8 | rio gallegos
# Processing Record 49 of the Set 8 | praia
# Processing Record 50 of the Set 8 | ocala
# Processing Record 1 of the Set 9 | salalah
# Processing Record 2 of the Set 9 | broken hill
# Processing Record 3 of the Set 9 | deputatskiy
# Processing Record 4 of the Set 9 | aquiraz
# Processing Record 5 of the Set 9 | evensk
# Processing Record 6 of the Set 9 | leopold
# Processing Record 7 of the Set 9 | pevek
# Processing Record 8 of the Set 9 | athabasca
# Processing Record 9 of the Set 9 | bagdarin
# Processing Record 10 of the Set 9 | aswan
# Processing Record 11 of the Set 9 | trincomalee
# Processing Record 12 of the Set 9 | steinbach
# Processing Record 13 of the Set 9 | tapaua
# Processing Record 14 of the Set 9 | port elizabeth
# Processing Record 15 of the Set 9 | khrebtovaya
# Processing Record 16 of the Set 9 | upington
# Processing Record 17 of the Set 9 | dingle
# Processing Record 18 of the Set 9 | attawapiskat
# Processing Record 19 of the Set 9 | bathsheba
# Processing Record 20 of the Set 9 | kondopoga
# Processing Record 21 of the Set 9 | jinchengjiang
# Processing Record 22 of the Set 9 | klaksvik
# City not found. Skipping...
# Processing Record 23 of the Set 9 | faya
# Processing Record 24 of the Set 9 | sandpoint
# Processing Record 25 of the Set 9 | peniche
# Processing Record 26 of the Set 9 | waipawa
# Processing Record 27 of the Set 9 | fairbanks
# Processing Record 28 of the Set 9 | broome
# Processing Record 29 of the Set 9 | tautira
# Processing Record 30 of the Set 9 | ancud
# Processing Record 31 of the Set 9 | seoul
# Processing Record 32 of the Set 9 | ankang
# Processing Record 33 of the Set 9 | pimentel
# Processing Record 34 of the Set 9 | qurayyat
# Processing Record 35 of the Set 9 | nipawin
# Processing Record 36 of the Set 9 | caravelas
# Processing Record 37 of the Set 9 | kaitangata
# Processing Record 38 of the Set 9 | kahului
# Processing Record 39 of the Set 9 | jujuy
# Processing Record 40 of the Set 9 | nguiu
# Processing Record 41 of the Set 9 | mabaruma
# Processing Record 42 of the Set 9 | ostrovnoy
# Processing Record 43 of the Set 9 | tasbuget
# Processing Record 44 of the Set 9 | tazovskiy
# Processing Record 45 of the Set 9 | zolotinka
# Processing Record 46 of the Set 9 | newry
# Processing Record 47 of the Set 9 | sao sebastiao do passe
# Processing Record 48 of the Set 9 | urusha
# Processing Record 49 of the Set 9 | kodinsk
# Processing Record 50 of the Set 9 | nemuro
# Processing Record 1 of the Set 10 | djibo
# Processing Record 2 of the Set 10 | qaqortoq
# Processing Record 3 of the Set 10 | adrar
# Processing Record 4 of the Set 10 | west des moines
# Processing Record 5 of the Set 10 | narsaq
# Processing Record 6 of the Set 10 | mackenzie
# Processing Record 7 of the Set 10 | cockburn town
# Processing Record 8 of the Set 10 | marfino
# Processing Record 9 of the Set 10 | leninskiy
# Processing Record 10 of the Set 10 | aksu
# Processing Record 11 of the Set 10 | bolungarvik
# Processing Record 12 of the Set 10 | qingdao
# Processing Record 13 of the Set 10 | rudbar
# City not found. Skipping...
# Processing Record 14 of the Set 10 | vestmannaeyjar
# Processing Record 15 of the Set 10 | neuquen
# Processing Record 16 of the Set 10 | dzhusaly
# Processing Record 17 of the Set 10 | dolbeau
# Processing Record 18 of the Set 10 | saleaula
# City not found. Skipping...
# Processing Record 19 of the Set 10 | yerbogachen
# Processing Record 20 of the Set 10 | vanavara
# Processing Record 21 of the Set 10 | chumikan
# Processing Record 22 of the Set 10 | dalmatovo
# Processing Record 23 of the Set 10 | oranjemund
# Processing Record 24 of the Set 10 | dhidhdhoo
# Processing Record 25 of the Set 10 | nantucket
# Processing Record 26 of the Set 10 | belaya gora
# Processing Record 27 of the Set 10 | iquitos
# Processing Record 28 of the Set 10 | ulladulla
# Processing Record 29 of the Set 10 | resistencia
# Processing Record 30 of the Set 10 | port hardy
# Processing Record 31 of the Set 10 | sungairaya
# Processing Record 32 of the Set 10 | saint-georges
# Processing Record 33 of the Set 10 | doka
# Processing Record 34 of the Set 10 | maceio
# Processing Record 35 of the Set 10 | kimparana
# Processing Record 36 of the Set 10 | inta
# Processing Record 37 of the Set 10 | sao joao da barra
# Processing Record 38 of the Set 10 | west bay
# Processing Record 39 of the Set 10 | warqla
# Processing Record 40 of the Set 10 | tabas
# Processing Record 41 of the Set 10 | boras
# Processing Record 42 of the Set 10 | freiberg
# Processing Record 43 of the Set 10 | lhuntshi
# City not found. Skipping...
# Processing Record 44 of the Set 10 | petropavlovsk-kamchatskiy
# Processing Record 45 of the Set 10 | nenjiang
# Processing Record 46 of the Set 10 | padang
# Processing Record 47 of the Set 10 | shuya
# Processing Record 48 of the Set 10 | komsomolskiy
# Processing Record 49 of the Set 10 | lingao
# Processing Record 50 of the Set 10 | lima
# Processing Record 1 of the Set 11 | sindor
# Processing Record 2 of the Set 11 | ponta do sol
# Processing Record 3 of the Set 11 | pangody
# Processing Record 4 of the Set 11 | kholodnyy
# Processing Record 5 of the Set 11 | luwuk
# Processing Record 6 of the Set 11 | raduzhnyy
# Processing Record 7 of the Set 11 | burica
# City not found. Skipping...
# Processing Record 8 of the Set 11 | muroto
# Processing Record 9 of the Set 11 | skagastrond
# Processing Record 10 of the Set 11 | rock falls
# Processing Record 11 of the Set 11 | pangkalanbuun
# Processing Record 12 of the Set 11 | nacala
# Processing Record 13 of the Set 11 | lamu
# Processing Record 14 of the Set 11 | acuna
# Processing Record 15 of the Set 11 | argudan
# Processing Record 16 of the Set 11 | atka
# Processing Record 17 of the Set 11 | evanston
# Processing Record 18 of the Set 11 | matsuura
# Processing Record 19 of the Set 11 | kyabe
# Processing Record 20 of the Set 11 | kariba
# Processing Record 21 of the Set 11 | carahue
# Processing Record 22 of the Set 11 | amapa
# Processing Record 23 of the Set 11 | port huron
# Processing Record 24 of the Set 11 | kattivakkam
# Processing Record 25 of the Set 11 | huilong
# Processing Record 26 of the Set 11 | orhangazi
# Processing Record 27 of the Set 11 | hamilton
# Processing Record 28 of the Set 11 | jackson
# Processing Record 29 of the Set 11 | tarija
# Processing Record 30 of the Set 11 | nova olimpia
# Processing Record 31 of the Set 11 | sioux lookout
# Processing Record 32 of the Set 11 | ucluelet
# Processing Record 33 of the Set 11 | ati
# Processing Record 34 of the Set 11 | haibowan
# Processing Record 35 of the Set 11 | alofi
# Processing Record 36 of the Set 11 | mudyuga
# Processing Record 37 of the Set 11 | mufulira
# Processing Record 38 of the Set 11 | levelland
# Processing Record 39 of the Set 11 | khairagarh
# Processing Record 40 of the Set 11 | salinas
# Processing Record 41 of the Set 11 | pitimbu
# Processing Record 42 of the Set 11 | bure
# Processing Record 43 of the Set 11 | siparia
# Processing Record 44 of the Set 11 | pak phanang
# Processing Record 45 of the Set 11 | carutapera
# Processing Record 46 of the Set 11 | ottumwa
# Processing Record 47 of the Set 11 | douentza
# Processing Record 48 of the Set 11 | srandakan
# Processing Record 49 of the Set 11 | marathon
# Processing Record 50 of the Set 11 | chuy
# Processing Record 1 of the Set 12 | naze
# Processing Record 2 of the Set 12 | lamar
# Processing Record 3 of the Set 12 | pouebo
# Processing Record 4 of the Set 12 | ufimskiy
# Processing Record 5 of the Set 12 | saint-pierre
# Processing Record 6 of the Set 12 | los andes
# Processing Record 7 of the Set 12 | boshnyakovo
# Processing Record 8 of the Set 12 | maloshuyka
# Processing Record 9 of the Set 12 | ciudad bolivar
# Processing Record 10 of the Set 12 | kalabo
# Processing Record 11 of the Set 12 | goderich
# Processing Record 12 of the Set 12 | verkhniye tatyshly
# Processing Record 13 of the Set 12 | flin flon
# Processing Record 14 of the Set 12 | kresttsy
# Processing Record 15 of the Set 12 | kuusamo
# Processing Record 16 of the Set 12 | lorengau
# Processing Record 17 of the Set 12 | miandrivazo
# Processing Record 18 of the Set 12 | cape canaveral
# Processing Record 19 of the Set 12 | waddan
# Processing Record 20 of the Set 12 | nokaneng
# Processing Record 21 of the Set 12 | asuncion nochixtlan
# Processing Record 22 of the Set 12 | addis abeba
# Processing Record 23 of the Set 12 | terrace
# Processing Record 24 of the Set 12 | pandan
# Processing Record 25 of the Set 12 | strezhevoy
# Processing Record 26 of the Set 12 | brantford
# Processing Record 27 of the Set 12 | krasnoselkup
# Processing Record 28 of the Set 12 | haines junction
# Processing Record 29 of the Set 12 | the valley
# Processing Record 30 of the Set 12 | deniliquin
# Processing Record 31 of the Set 12 | tiksi
# Processing Record 32 of the Set 12 | jieshi
# Processing Record 33 of the Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 34 of the Set 12 | chincholi
# Processing Record 35 of the Set 12 | namibe
# Processing Record 36 of the Set 12 | south venice
# Processing Record 37 of the Set 12 | sabla
# Processing Record 38 of the Set 12 | cervo
# Processing Record 39 of the Set 12 | severodvinsk
# Processing Record 40 of the Set 12 | sorland
# Processing Record 41 of the Set 12 | lolua
# City not found. Skipping...
# Processing Record 42 of the Set 12 | basco
# Processing Record 43 of the Set 12 | asau
# City not found. Skipping...
# Processing Record 44 of the Set 12 | port blair
# Processing Record 45 of the Set 12 | pochutla
# Processing Record 46 of the Set 12 | brookings
# Processing Record 47 of the Set 12 | neiafu
# Processing Record 48 of the Set 12 | kushmurun
# Processing Record 49 of the Set 12 | zhenjiang
# Processing Record 50 of the Set 12 | lake havasu city
# Processing Record 1 of the Set 13 | shimanovsk
# Processing Record 2 of the Set 13 | krasnovishersk
# Processing Record 3 of the Set 13 | cortez
# Processing Record 4 of the Set 13 | healdsburg
# Processing Record 5 of the Set 13 | muncar
# Processing Record 6 of the Set 13 | ravar
# Processing Record 7 of the Set 13 | el sauzal
# Processing Record 8 of the Set 13 | qostanay
# Processing Record 9 of the Set 13 | analipsis
# Processing Record 10 of the Set 13 | guajara-mirim
# Processing Record 11 of the Set 13 | riviere-au-renard
# Processing Record 12 of the Set 13 | noyabrsk
# Processing Record 13 of the Set 13 | sistranda
# Processing Record 14 of the Set 13 | den helder
# Processing Record 15 of the Set 13 | kibondo
# Processing Record 16 of the Set 13 | phan thiet
# Processing Record 17 of the Set 13 | plouzane
# Processing Record 18 of the Set 13 | benghazi
# Processing Record 19 of the Set 13 | marsh harbour
# Processing Record 20 of the Set 13 | san vicente
# Processing Record 21 of the Set 13 | san carlos de bariloche
# Processing Record 22 of the Set 13 | banda aceh
# Processing Record 23 of the Set 13 | makushino
# Processing Record 24 of the Set 13 | utiroa
# Processing Record 25 of the Set 13 | barao de melgaco
# Processing Record 26 of the Set 13 | tynda
# Processing Record 27 of the Set 13 | altay
# Processing Record 28 of the Set 13 | pokanayevka
# Processing Record 29 of the Set 13 | crisan
# Processing Record 30 of the Set 13 | tezu
# Processing Record 31 of the Set 13 | kuching
# Processing Record 32 of the Set 13 | zigong
# Processing Record 33 of the Set 13 | lensk
# Processing Record 34 of the Set 13 | itoman
# Processing Record 35 of the Set 13 | eyl
# Processing Record 36 of the Set 13 | ketchikan
# Processing Record 37 of the Set 13 | meyungs
# Processing Record 38 of the Set 13 | riyadh
# Processing Record 39 of the Set 13 | mecca
# Processing Record 40 of the Set 13 | joshimath
# Processing Record 41 of the Set 13 | gat
# Processing Record 42 of the Set 13 | kasungu
# Processing Record 43 of the Set 13 | cassilandia
# Processing Record 44 of the Set 13 | podor
# City not found. Skipping...
# Processing Record 45 of the Set 13 | betwagan
# Processing Record 46 of the Set 13 | auray
# Processing Record 47 of the Set 13 | egvekinot
# Processing Record 48 of the Set 13 | sainte-rose
# Processing Record 49 of the Set 13 | richards bay
# Processing Record 50 of the Set 13 | bairiki
# Processing Record 1 of the Set 14 | beloha
# Processing Record 2 of the Set 14 | north platte
# Processing Record 3 of the Set 14 | taoudenni
# Processing Record 4 of the Set 14 | taga dzong
# City not found. Skipping...
# Processing Record 5 of the Set 14 | whitehorse
# Processing Record 6 of the Set 14 | verkhniy lomov
# Processing Record 7 of the Set 14 | lethem
# Processing Record 8 of the Set 14 | okha
# Processing Record 9 of the Set 14 | usinsk
# Processing Record 10 of the Set 14 | dankaur
# Processing Record 11 of the Set 14 | januaria
# Processing Record 12 of the Set 14 | kenitra
# Processing Record 13 of the Set 14 | saint johnsbury
# Processing Record 14 of the Set 14 | phan rang
# Processing Record 15 of the Set 14 | chengmai
# Processing Record 16 of the Set 14 | kedrovyy
# Processing Record 17 of the Set 14 | pachino
# Processing Record 18 of the Set 14 | port moresby
# Processing Record 19 of the Set 14 | oranjestad
# Processing Record 20 of the Set 14 | yar-sale
# Processing Record 21 of the Set 14 | fougamou
# Processing Record 22 of the Set 14 | kobojango
# Processing Record 23 of the Set 14 | bud
# Processing Record 24 of the Set 14 | key west
# Processing Record 25 of the Set 14 | vila
# Processing Record 26 of the Set 14 | puerto colombia
# Processing Record 27 of the Set 14 | sarangani
# Processing Record 28 of the Set 14 | panguna
# Processing Record 29 of the Set 14 | gorno-chuyskiy
# Processing Record 30 of the Set 14 | narathiwat
# Processing Record 31 of the Set 14 | berezovyy
# Processing Record 32 of the Set 14 | wewak
# Processing Record 33 of the Set 14 | pokrovsk-uralskiy
# Processing Record 34 of the Set 14 | novoagansk
# Processing Record 35 of the Set 14 | amparafaravola
# Processing Record 36 of the Set 14 | xingyi
# Processing Record 37 of the Set 14 | mocuba
# Processing Record 38 of the Set 14 | kokopo
# Processing Record 39 of the Set 14 | arlit
# Processing Record 40 of the Set 14 | mandalgovi
# Processing Record 41 of the Set 14 | sawtell
# Processing Record 42 of the Set 14 | zhangye
# Processing Record 43 of the Set 14 | dawson creek
# Processing Record 44 of the Set 14 | dolinsk
# Processing Record 45 of the Set 14 | satara
# Processing Record 46 of the Set 14 | sakaiminato
# Processing Record 47 of the Set 14 | tooele
# Processing Record 48 of the Set 14 | hovd
# Processing Record 49 of the Set 14 | miramar
# Processing Record 50 of the Set 14 | ilheus
# Processing Record 1 of the Set 15 | srednekolymsk
# Processing Record 2 of the Set 15 | balakhninskiy
# Processing Record 3 of the Set 15 | comodoro rivadavia
# Processing Record 4 of the Set 15 | lienz
# Processing Record 5 of the Set 15 | bolshegrivskoye
# Processing Record 6 of the Set 15 | sandovo
# Processing Record 7 of the Set 15 | juigalpa
# Processing Record 8 of the Set 15 | manzanillo
# Processing Record 9 of the Set 15 | inisa
# Processing Record 10 of the Set 15 | hanyang
# Processing Record 11 of the Set 15 | talakan
# Processing Record 12 of the Set 15 | bandundu
# Processing Record 13 of the Set 15 | belyy yar
# Processing Record 14 of the Set 15 | guasdualito
# Processing Record 15 of the Set 15 | kuruman
# Processing Record 16 of the Set 15 | fort nelson
# Processing Record 17 of the Set 15 | uyuni
# Processing Record 18 of the Set 15 | nabire
# Processing Record 19 of the Set 15 | kloulklubed
# Processing Record 20 of the Set 15 | tahoua
# Processing Record 21 of the Set 15 | sao felix do xingu
# Processing Record 22 of the Set 15 | barreiras
# Processing Record 23 of the Set 15 | kabalo
# Processing Record 24 of the Set 15 | ampanihy
# Processing Record 25 of the Set 15 | lisakovsk
# Processing Record 26 of the Set 15 | kaeo
# Processing Record 27 of the Set 15 | danjiangkou
# Processing Record 28 of the Set 15 | vagur
# Processing Record 29 of the Set 15 | bac can
# Processing Record 30 of the Set 15 | rawson
# Processing Record 31 of the Set 15 | sulangan
# Processing Record 32 of the Set 15 | nyagan
# Processing Record 33 of the Set 15 | sinjar
# Processing Record 34 of the Set 15 | ballina
# Processing Record 35 of the Set 15 | ilo
# Processing Record 36 of the Set 15 | lisala
# Processing Record 37 of the Set 15 | aracatuba
# Processing Record 38 of the Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 39 of the Set 15 | santa rosa
# Processing Record 40 of the Set 15 | ye
# Processing Record 41 of the Set 15 | yuryuzan
# Processing Record 42 of the Set 15 | xapuri
# Processing Record 43 of the Set 15 | chardara
# Processing Record 44 of the Set 15 | malanville
# Processing Record 45 of the Set 15 | jardim
# Processing Record 46 of the Set 15 | koslan
# Processing Record 47 of the Set 15 | bolshaya murta
# Processing Record 48 of the Set 15 | matagami
# Processing Record 49 of the Set 15 | laguna
# Processing Record 50 of the Set 15 | voka
# Processing Record 1 of the Set 16 | artyk
# Processing Record 2 of the Set 16 | dicabisagan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 725

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Zlobin      HR  45.2924   14.6541     60.10        59           0
# 1       Lobito      AO -12.3481   13.5456     75.92        87           5
# 2      Mataura      NZ -46.1927  168.8643     49.48        97          84
# 3  Grand Gaube      MU -20.0064   57.6608     75.60        79           4
# 4    Kyzyl-Suu      KG  42.3414   78.0056     55.96        49           0
#
#    Wind Speed Current Description
# 0       12.66           clear sky
# 1        3.91           clear sky
# 2        1.52       broken clouds
# 3        3.00           clear sky
# 4        5.46           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
